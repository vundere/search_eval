# %% [markdown]
# # Assignment 2 - Part B: Building a decision tree

# %% [markdown]
# This is a skeleton of a decision tree classifier for the example data set in `data/example.csv`.

# %%
import csv
import math
from statistics import median, mode
from collections import Counter
from enum import Enum

# %% [markdown]
# Some simple type definitions.

# %%
class AttrType(Enum):
    cat = 0  # categorical (qualitative) attribute
    num = 1  # numerical (quantitative) attribute
    target = 2  # target label


class NodeType(Enum):
    root = 0
    internal = 1
    leaf = 2


class SplitType(Enum):
    bin = 0  # binary split
    multi = 1  # multi-way split

# %% [markdown]
# Also, some basic classes to represent an attribute, a spltting procedure, and a node.

# %%
class Attribute(object):
    def __init__(self, label, type):
        assert type in AttrType
        self.label = label
        self.type = type
        self.stat = None  # holds mean for numerical and mode for categorical attributes


class Splitting(object):
    def __init__(self, attr, infogain, split_type, cond, splits):
        self.attr = attr  # attribute ID (index in ATTR)
        self.infogain = infogain  # information gain if splitting is done on this attribute
        self.split_type = split_type  # one of SplitType
        self.cond = cond  # splitting condition, i.e., values on outgoing edges
        self.splits = splits  # list of training records (IDs) for each slitting condition


class Node(object):
    def __init__(self, id, type, parent_id, children=None, edge_value=None, val=None, split_type=None, split_cond=None,
                 infogain=None):
        self.id = id  # ID (same as the index in DT.model list)
        self.type = type  # one of NodeType
        self.parent_id = parent_id  # ID of parent node (None if root)
        self.children = children  # list of IDs of child nodes
        self.edge_value = edge_value  # the value of the incoming edge (only if not root node)
        self.val = val  # if root or internal node: the attribute that is compared at that node; if leaf node: the target value
        self.split_type = split_type  # one of SplitType
        self.split_cond = split_cond  # splitting condition (median value for binary splits on numerical values; otherwise a list of categorical values (corresponding to child nodes))
        self.infogain = infogain

    def append_child(self, node_id):
        self.children.append(node_id)

# %% [markdown]
# The input filename is hard-coded.

# %%
INFILE = "data/basketball.train.csv"
TESTFILE = "data/basketball.test.csv"
OUTPUT_FILE = "data/dt_basketball.pred.csv"


def load_test_data():
        with open(TESTFILE) as csvfile:
            data = []
            csvreader = csv.reader(csvfile, delimiter=',')
            for row in csvreader:
                rec = []
                for i in range(len(ATTR) - 1):
                    val = row[i].strip()
                    # convert numerical attributes
                    if ATTR[i].type == AttrType.num:  # Note that this will break for "?" (missing attribute)
                        val = float(val)
                    rec.append(val)
                data.append(rec)
        return data

# %% [markdown]
# The attribute labels types are hard-coded too (the same order as in the file!).

# %%
ATTR = [Attribute("LOCATION", AttrType.cat), Attribute("W", AttrType.cat),
        Attribute("FINAL_MARGIN", AttrType.num), Attribute("SHOT_NUMBER", AttrType.num), 
        Attribute("PERIOD", AttrType.cat), Attribute("GAME_CLOCK", AttrType.num), 
        Attribute("SHOT_CLOCK", AttrType.num), Attribute("DRIBBLES", AttrType.num), 
        Attribute("TOUCH_TIME", AttrType.num), Attribute("SHOT_DIST", AttrType.num),
        Attribute("PTS_TYPE", AttrType.cat), Attribute("CLOSE_DEF_DIST", AttrType.num),
        Attribute("Target", AttrType.target)]

# %% [markdown]
# The index of the target attribute (assuming it's the last).

# %%
IDX_TARGET = len(ATTR) - 1

# %% [markdown]
# A main class DT representing the decision tree classifier. It could represent with methods:
#
#   - a given inpurity measure;
#   - the search for the best attribute to split with;
#   - the addition of a node to the tree;
#   - a convenient model printer;
#   - the recursive call for obtaining a tree;
#   - a builder and an applier.

# %%
class DT(object):
    def __init__(self):
        self.data = None  # training data set (loaded into memory)
        self.model = None  # decision tree model
        self.default_class = None  # default target class

    def __load_data(self):
        with open(INFILE) as csvfile:
            self.data = []
            csvreader = csv.reader(csvfile, delimiter=',')
            for row in csvreader:
                rec = []
                for i in range(len(ATTR)):
                    val = row[i].strip()
                    # convert numerical attributes
                    if ATTR[i].type == AttrType.num:  # Note that this will break for "?" (missing attribute)
                        val = float(val)
                    rec.append(val)
                # print(rec)
                self.data.append(rec)
                # self.data.append([element.strip() for element in row])  # strip spaces
                
    
    def __median(self, attrNum):
        attrList = []
        
        for i in range(0, len(self.data)):
            attrList.append(self.data[i][attrNum])
            
        return median(attrList)
        

    def __entropy(self, records):
        """
        Calculates entropy for a selection of records.

        :param records: Data records (given by indices)
        """
        yes = 0
        no = 0

        for r in records:
            if (self.data[r][IDX_TARGET] == "made"):
                yes += 1
            if (self.data[r][IDX_TARGET] == "missed"):
                no += 1

        entropy = -no/(no+yes)*math.log2(no/(no+yes)) - yes/(no+yes)*math.log2(yes/(no+yes))

        return entropy

    
    def __find_best_attr(self, attrs, records):
        """
        Finds the attribute with the largest gain.

        :param attrs: Set of attributes
        :param records: Training set (list of record ids)
        :return:
        """
        entropy_p = self.__entropy(records)  # parent's entropy
        splittings = []  # holds the splitting information for each attribute

        for a in attrs:
            assert ATTR[a].type in AttrType
            splits = {}  # record IDs corresponding to each split
            split_mode = None
            split_cond = None
            # splitting condition depends on the attribute type
            if ATTR[a].type == AttrType.target:  # skip target attribute
                continue
            elif ATTR[a].type == AttrType.cat:  # categorical attribute
                # multi-way split on each possible value
                split_mode = SplitType.multi
                # each possible attr value corresponds to a split (indexed with categorical labels)
                # Note: it's important to consider attr values from the entire training set
                split_cond = set([self.data[idx][a] for idx in range(len(self.data))])
                
                # `splits[val]` holds a list of records for a given split,
                # where `val` is an element of `split_cond`
                for e in split_cond:
                    splits[e] = []
                    for r in records:
                        if self.data[r][a] == e:
                            splits[e].append(r)
                
            elif ATTR[a].type == AttrType.num:  # numerical attribute => binary split on median value
                split_mode = SplitType.bin
                split_cond = self.__median(a)  # (i.e., if less or equal than this value)
                        
                greater = []
                less_equal = []

                for r in records:
                    if(self.data[r][a] > split_cond):
                        greater.append(r)
                    elif (self.data[r][a] <= split_cond):
                        less_equal.append(r)

                str = "<=" + repr(split_cond)
                splits[str] = less_equal
                str = ">" + repr(split_cond)
                splits[str] = greater

            # compute gain for attribute a
            infogain = entropy_p

            for split in splits:
                yes = 0
                no = 0
                
                for r in splits[split]:
                    if (self.data[r][IDX_TARGET] == "made"):
                         yes += 1
                    if (self.data[r][IDX_TARGET] == "missed"):
                        no += 1        
                
                if(no == 0 and yes == 0):
                    entropy = 1
                elif(no == 0 or yes == 0):
                    entropy = 0
                else:
                    entropy = -no / (no + yes) * math.log2(no / (no + yes)) - yes / (no + yes) * math.log2(yes / (no + yes))
                
                infogain -= ((yes + no) / len(records)) * entropy
                
            print("Information Gain for attribute {0}: {1}".format(ATTR[a].label, infogain))

            splitting = Splitting(a, infogain, split_mode, split_cond, splits)
            splittings.append(splitting)

        # find best splitting
        best_splitting = sorted(splittings, key=lambda x: x.infogain, reverse=True)[0]
        return best_splitting

    def __add_node(self, parent_id, node_type=NodeType.internal, edge_value=None, val=None, split_type=None,
                   split_cond=None):
        """
        Adds a node to the decision tree.

        :param parent_id:
        :param node_type:
        :param edge_value:
        :param val:
        :param split_type:
        :param split_cond:
        :return:
        """
        node_id = len(self.model)  # id of the newly assigned node
        if not self.model:  # the tree is empty
            node_type = NodeType.root

        node = Node(node_id, node_type, parent_id, children=[], edge_value=edge_value, val=val, split_type=split_type,
                    split_cond=split_cond)
        self.model.append(node)

        # also add it as a child of the parent node
        if parent_id is not None:
            self.model[parent_id].append_child(node_id)

        return node_id

    def __id3(self, attrs, records, parent_id=None, value=None):
        """
        Function ID3 that returns a decision tree.

        :param attrs: Set of attributes
        :param records: Training set (list of record ids)
        :param parent_id: ID of parent node
        :param value: Value corresponding to the parent attribute, i.e., label of the edge on which we arrived to this node
        :return:
        """
        # empty training set or empty set of attributes => create leaf node with default class
        if not records or not attrs:
            self.__add_node(parent_id, node_type=NodeType.leaf, edge_value=value, val=self.default_class)
            return

        # if all records have the same target value => create leaf node with that target value
        same = all(self.data[idx][IDX_TARGET] == self.data[records[0]][IDX_TARGET] for idx in records)
        if same:
            target = self.data[records[0]][IDX_TARGET]
            self.__add_node(parent_id, node_type=NodeType.leaf, edge_value=value, val=target)
            return

        # find the attribute with the largest gain
        splitting = self.__find_best_attr(attrs, records)
        # add node
        node_id = self.__add_node(parent_id, edge_value=value, val=splitting.attr, 
                                  split_type=splitting.split_type, split_cond=splitting.cond)
        
        print('\nWorking . . .')

        newattrs = attrs.copy()
        newattrs.remove(splitting.attr)

        if(splitting.split_type == SplitType.bin):
            less_equal = []
            greater = []
            for r in records:
                if (self.data[r][splitting.attr] > splitting.cond):
                    greater.append(r)
                elif (self.data[r][splitting.attr] <= splitting.cond):
                    less_equal.append(r)
            self.__id3(newattrs, greater, parent_id=node_id, value=False)
            self.__id3(newattrs, less_equal, parent_id=node_id, value=True)

        if(splitting.split_type == SplitType.multi):
            for sc in splitting.cond:
                subset = []
                for r in records:
                    if(self.data[r][splitting.attr] == sc):
                        subset.append(r)
                self.__id3(newattrs, subset, parent_id=node_id, value=sc)
                

    def print_model(self, node_id=0, level=0):
        node = self.model[node_id]
        indent = "  " * level
        if node.type == NodeType.leaf:
            print(indent + str(node.edge_value) + " [Leaf node] class=" + node.val)
        else:
            cond = " <= " + str(node.split_cond) if ATTR[node.val].type == AttrType.num else " == ? "
            if node.type == NodeType.root:
                print("[Root node] '" + ATTR[node.val].label + "'" + cond)
            else:
                print(indent + str(node.edge_value) + " [Internal node] '" + ATTR[node.val].label + "'" + cond)
            # print tree for child notes recursively
            for n_id in node.children:
                self.print_model(n_id, level + 1)

    def build_model(self):
        self.__load_data()
        self.model = []  # holds the decision tree model, represented as a list of nodes
        # Get majority class
        #   Note: Counter returns a dictionary, most_common(x) returns a list with the x most common elements as
        #         (key, count) tuples; we need to take the first element of the list and the first element of the tuple
        self.default_class = Counter([x[IDX_TARGET] for x in self.data]).most_common(1)[0][0]
        self.__id3(set(range(len(ATTR) - 1)), list(range(len(self.data))))

    def apply_model(self, record):
        node = self.model[0]
        while node.type != NodeType.leaf:
            # TODO based on the value of the record's attribute that is tested in `node`,
            # set `node` to one of its child nodes until a leaf node is reached
            attr_val = record[node.val]

            if ATTR[node.val].type == AttrType.num:
                if record[node.val] > node.split_cond:
                    edge = False
                elif record[node.val] <= node.split_cond:
                    edge = True
            else:
                edge = attr_val

            for child_id in node.children:
                child_edge_value = self.model[child_id].edge_value

                if self.model[child_id].edge_value == edge:
                    node = self.model[child_id]
                    
        return node.val

# %% [markdown]
# Finally, the main function building a decision tree model, printing it and applying it on some unseen records.

# %%
def main():
    dt = DT()
    print("Build model:")
    dt.build_model()
    dt.print_model()
    
    test = load_test_data()

    print("\nApply model:")
    with open(OUTPUT_FILE, 'w') as output:
        output.write("Id,Target\n")
        for id, data in enumerate(test):
            res = dt.apply_model(data)
            output.write("%s,%s\n" % (id + 1, res))
    print("Results written to {0}".format(OUTPUT_FILE))


if __name__ == "__main__":
    main()
# Out:
# Build model:
# Information Gain for attribute LOCATION: 0.0001403197935238576
# Information Gain for attribute W: 0.0015119418826527453
# Information Gain for attribute FINAL_MARGIN: 0.0013424812401782171
# Information Gain for attribute SHOT_NUMBER: 0.00010174272372082127
# Information Gain for attribute PERIOD: 0.00026749841779211136
# Information Gain for attribute GAME_CLOCK: 1.882332878455628e-08
# Information Gain for attribute SHOT_CLOCK: 0.003105048901265617
# Information Gain for attribute DRIBBLES: 0.0014535159128711284
# Information Gain for attribute TOUCH_TIME: 0.002509204053641023
# Information Gain for attribute SHOT_DIST: 0.017133483068884237
# Information Gain for attribute PTS_TYPE: 0.01102213028657592
# Information Gain for attribute CLOSE_DEF_DIST: 0.00042678007200808166
#
# Working . . .
# Information Gain for attribute LOCATION: 0.00015536978745817054
# Information Gain for attribute W: 0.0020081897525431325
# Information Gain for attribute FINAL_MARGIN: 0.0018171489324245171
# Information Gain for attribute SHOT_NUMBER: 0.00032436946179481563
# Information Gain for attribute PERIOD: 0.0007576406786531098
# Information Gain for attribute GAME_CLOCK: 4.736908034097542e-05
# Information Gain for attribute SHOT_CLOCK: 0.0002702913038006294
# Information Gain for attribute DRIBBLES: 0.00046034152996238253
# Information Gain for attribute TOUCH_TIME: 0.00041758273625458475
# Information Gain for attribute PTS_TYPE: 0.002523772641400912
# Information Gain for attribute CLOSE_DEF_DIST: 0.0015105118111212734
#
# Working . . .
# Information Gain for attribute LOCATION: 6.473405617007932e-05
# Information Gain for attribute W: 0.001580543404341772
# Information Gain for attribute FINAL_MARGIN: 0.0013306932163817953
# Information Gain for attribute SHOT_NUMBER: 0.0001325838971750204
# Information Gain for attribute PERIOD: 0.0008909652242496124
# Information Gain for attribute GAME_CLOCK: 0.00010898599482589422
# Information Gain for attribute SHOT_CLOCK: 0.00044328761594208954
# Information Gain for attribute DRIBBLES: 0.002126689505673185
# Information Gain for attribute TOUCH_TIME: 0.0019137310904566718
# Information Gain for attribute CLOSE_DEF_DIST: 0.0029147154062714176
#
# Working . . .
# Information Gain for attribute LOCATION: 2.582927248273581e-05
# Information Gain for attribute W: 0.001260033160801366
# Information Gain for attribute FINAL_MARGIN: 0.0008530647944801628
# Information Gain for attribute SHOT_NUMBER: 3.3785998351576474e-05
# Information Gain for attribute PERIOD: 0.0007607778043048352
# Information Gain for attribute GAME_CLOCK: 2.7314946094536552e-05
# Information Gain for attribute SHOT_CLOCK: 5.4288788122081044e-05
# Information Gain for attribute DRIBBLES: 0.001552352755569475
# Information Gain for attribute TOUCH_TIME: 0.001619225053481388
#
# Working . . .
# Information Gain for attribute LOCATION: 1.1510207502174463e-05
# Information Gain for attribute W: 0.0013228361756942864
# Information Gain for attribute FINAL_MARGIN: 0.0008244618167445594
# Information Gain for attribute SHOT_NUMBER: 0.00021888347140974762
# Information Gain for attribute PERIOD: 0.0021452319620970384
# Information Gain for attribute GAME_CLOCK: 6.507666860755545e-05
# Information Gain for attribute SHOT_CLOCK: 0.0002028937374741746
# Information Gain for attribute DRIBBLES: 0.00022826925540819776
#
# Working . . .
# Information Gain for attribute LOCATION: 0.23645279766002802
# Information Gain for attribute W: 0.032268399663386294
# Information Gain for attribute FINAL_MARGIN: 0.032268399663386294
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.034144039029604056
# Information Gain for attribute DRIBBLES: 0.032268399663386294
#
# Working . . .
# Information Gain for attribute W: 0.3219280948873623
# Information Gain for attribute FINAL_MARGIN: 0.3219280948873623
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.01997309402197489
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.31127812445913283
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0005721553791024347
# Information Gain for attribute W: 0.0002931818308403722
# Information Gain for attribute FINAL_MARGIN: 4.5456858007830725e-05
# Information Gain for attribute SHOT_NUMBER: 0.00028316433404679264
# Information Gain for attribute GAME_CLOCK: 4.806915247845822e-06
# Information Gain for attribute SHOT_CLOCK: 8.875253564794017e-05
# Information Gain for attribute DRIBBLES: 7.923892237271524e-05
#
# Working . . .
# Information Gain for attribute W: 0.0014830819965546693
# Information Gain for attribute FINAL_MARGIN: 0.0018362771502759556
# Information Gain for attribute SHOT_NUMBER: 1.4429922918335336e-05
# Information Gain for attribute GAME_CLOCK: 0.0014544208582977225
# Information Gain for attribute SHOT_CLOCK: 3.227627598584304e-05
# Information Gain for attribute DRIBBLES: 1.3885177374439728e-05
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0008507913234590547
# Information Gain for attribute GAME_CLOCK: 0.005085416470656079
# Information Gain for attribute SHOT_CLOCK: 0.0007629814546840086
# Information Gain for attribute DRIBBLES: 8.458865579763497e-06
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0002654238577141643
# Information Gain for attribute SHOT_CLOCK: 0.013319141794394751
# Information Gain for attribute DRIBBLES: 8.822724555490602e-06
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.038022008940357205
# Information Gain for attribute DRIBBLES: 0.004315710118059646
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.1444867598454651
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.021324584318820783
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.017226595774997522
# Information Gain for attribute DRIBBLES: 0.003909727210652636
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.07028926629056709
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.002854538651193672
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.017084024488162708
# Information Gain for attribute SHOT_CLOCK: 0.004617128765818046
# Information Gain for attribute DRIBBLES: 8.9269625621613e-06
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.0016870383592330618
# Information Gain for attribute DRIBBLES: 0.002302487417604193
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.00014277854861444172
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.07205662510638444
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.010414794131454186
# Information Gain for attribute DRIBBLES: 0.005478729494017953
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.009693668617616447
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.0023146583577101643
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 1.9972198339601732e-08
# Information Gain for attribute SHOT_NUMBER: 0.00037878129799839844
# Information Gain for attribute GAME_CLOCK: 0.00035482108370943344
# Information Gain for attribute SHOT_CLOCK: 9.625612519492677e-06
# Information Gain for attribute DRIBBLES: 6.022057836729822e-06
#
# Working . . .
# Information Gain for attribute W: 0.0008179267247211408
# Information Gain for attribute GAME_CLOCK: 4.08187747096278e-05
# Information Gain for attribute SHOT_CLOCK: 0.0007993880909141216
# Information Gain for attribute DRIBBLES: 7.940285395791058e-05
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.01997309402197489
# Information Gain for attribute SHOT_CLOCK: 0.01997309402197489
# Information Gain for attribute DRIBBLES: 0.19919117293110944
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.01780102730053701
# Information Gain for attribute SHOT_CLOCK: 0.01780102730053701
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.01997309402197489
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.07376130822286725
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0003475300315443075
# Information Gain for attribute SHOT_CLOCK: 0.00034395453506436136
# Information Gain for attribute DRIBBLES: 0.0006015140240027694
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0012856697311746657
# Information Gain for attribute SHOT_CLOCK: 3.114230880341129e-06
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.014065411929277238
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.0019322374362768513
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0040690552769112875
# Information Gain for attribute SHOT_CLOCK: 0.011265848648557342
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 5.551115123125783e-17
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.006683789088162806
#
# Working . . .
# Information Gain for attribute W: 0.00022410884749890503
# Information Gain for attribute GAME_CLOCK: 0.00026083605608762106
# Information Gain for attribute SHOT_CLOCK: 8.702082548689427e-05
# Information Gain for attribute DRIBBLES: 0.00010041020725815031
#
# Working . . .
# Information Gain for attribute W: 9.218366600505234e-06
# Information Gain for attribute SHOT_CLOCK: 0.010265954922413556
# Information Gain for attribute DRIBBLES: 1.046278833483072e-05
#
# Working . . .
# Information Gain for attribute W: 3.092643451951815e-05
# Information Gain for attribute DRIBBLES: 9.778487989642315e-05
#
# Working . . .
# Information Gain for attribute W: 2.6856429380606173e-05
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0001380785426567943
# Information Gain for attribute DRIBBLES: 0.00020657473743312948
#
# Working . . .
# Information Gain for attribute W: 0.00015103247109737872
#
# Working . . .
# Information Gain for attribute W: 0.044673614309123866
#
# Working . . .
# Information Gain for attribute W: 0.0011788186879984064
# Information Gain for attribute SHOT_CLOCK: 0.022066601552277243
# Information Gain for attribute DRIBBLES: 0.00047129218133123985
#
# Working . . .
# Information Gain for attribute W: 0.007522602054955918
# Information Gain for attribute DRIBBLES: 0.010828331759200838
#
# Working . . .
# Information Gain for attribute W: 0.0003135470062418655
#
# Working . . .
# Information Gain for attribute W: 0.8112781244591328
#
# Working . . .
# Information Gain for attribute W: 0.013485346213716998
# Information Gain for attribute DRIBBLES: 0.002847612027380486
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.14269027946047552
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.00016296453298758617
#
# Working . . .
# Information Gain for attribute W: 3.6737054356916765e-06
# Information Gain for attribute FINAL_MARGIN: 0.0005354264536020503
# Information Gain for attribute SHOT_NUMBER: 0.0017136356110249995
# Information Gain for attribute GAME_CLOCK: 0.00212909328660682
# Information Gain for attribute SHOT_CLOCK: 0.0006768428083215872
# Information Gain for attribute DRIBBLES: 0.0001687007105075633
#
# Working . . .
# Information Gain for attribute W: 7.484816833891461e-05
# Information Gain for attribute FINAL_MARGIN: 0.0010333783630728233
# Information Gain for attribute SHOT_NUMBER: 0.0003996184512065626
# Information Gain for attribute SHOT_CLOCK: 0.005434097871563903
# Information Gain for attribute DRIBBLES: 0.0003996184512066181
#
# Working . . .
# Information Gain for attribute W: 0.005370017857891318
# Information Gain for attribute FINAL_MARGIN: 0.0014852334326810324
# Information Gain for attribute SHOT_NUMBER: 0.00494220440682
# Information Gain for attribute DRIBBLES: 0.0018662411660127498
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.03116059643927671
# Information Gain for attribute SHOT_NUMBER: 0.04243289393195976
# Information Gain for attribute DRIBBLES: 0.017779176642943484
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute DRIBBLES: 0.03637309922189935
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.031245196500138017
# Information Gain for attribute DRIBBLES: 0.01769400253070219
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.016114532159930306
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.010974263760688857
# Information Gain for attribute DRIBBLES: 0.004669800016791514
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute DRIBBLES: 0.010581027529542486
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.004138294333851433
# Information Gain for attribute FINAL_MARGIN: 0.006839784519137915
# Information Gain for attribute SHOT_NUMBER: 0.0002852473043908621
# Information Gain for attribute DRIBBLES: 7.891993780495543e-05
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.003993629703220786
# Information Gain for attribute DRIBBLES: 0.0011393598385280868
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.0005988896698578827
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.002111627216580425
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.001887197967720522
# Information Gain for attribute SHOT_NUMBER: 0.001666357515875766
# Information Gain for attribute DRIBBLES: 0.0009978830056776022
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute DRIBBLES: 0.07278022578373267
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0012841610520727964
# Information Gain for attribute DRIBBLES: 7.322599214498737e-05
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.005977711423774124
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.001168948193386754
#
# Working . . .
# Information Gain for attribute W: 9.056760504294603e-05
# Information Gain for attribute FINAL_MARGIN: 0.00031698959016712713
# Information Gain for attribute SHOT_NUMBER: 0.0011689636247264046
# Information Gain for attribute SHOT_CLOCK: 0.0004968417863503993
# Information Gain for attribute DRIBBLES: 0.00011195799636387616
#
# Working . . .
# Information Gain for attribute W: 0.0011797757390772379
# Information Gain for attribute FINAL_MARGIN: 0.0006346265424771458
# Information Gain for attribute SHOT_CLOCK: 0.0009486775042510942
# Information Gain for attribute DRIBBLES: 4.467695802679028e-05
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0011120814820214653
# Information Gain for attribute SHOT_CLOCK: 0.00016346761354679717
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 3.166632805590153e-05
# Information Gain for attribute DRIBBLES: 0.0007084134007978582
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.0001441459272368273
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.0013397424044413464
#
# Working . . .
# Information Gain for attribute SHOT_CLOCK: 0.31127812445913283
# Information Gain for attribute DRIBBLES: 0.31127812445913283
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.2516291673878229
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.00870045720642243
# Information Gain for attribute DRIBBLES: 0.0003948199239107719
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute DRIBBLES: 0.09265128879158102
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute DRIBBLES: 0.0022299311896331053
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute W: 7.680994938191743e-05
# Information Gain for attribute FINAL_MARGIN: 0.002662732668711032
# Information Gain for attribute SHOT_CLOCK: 0.005337157473278786
# Information Gain for attribute DRIBBLES: 0.0007101531367350589
#
# Working . . .
# Information Gain for attribute W: 0.00023069731882036093
# Information Gain for attribute FINAL_MARGIN: 0.0005165103689025452
# Information Gain for attribute DRIBBLES: 0.0008222350874333983
#
# Working . . .
# Information Gain for attribute W: 0.0003204414006593992
# Information Gain for attribute FINAL_MARGIN: 0.0001305200189288258
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 9.703751106504566e-05
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.04277604849810834
# Information Gain for attribute FINAL_MARGIN: 0.0427760484981084
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 9.317090373006653e-05
# Information Gain for attribute FINAL_MARGIN: 0.005796822891107722
# Information Gain for attribute DRIBBLES: 0.00032118663437263884
#
# Working . . .
# Information Gain for attribute W: 0.0
# Information Gain for attribute DRIBBLES: 0.02366846635879738
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.0
#
# Working . . .
# Information Gain for attribute W: 0.03856323260583816
# Information Gain for attribute DRIBBLES: 0.007000498934087718
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.01327303853986872
#
# Working . . .
# Information Gain for attribute LOCATION: 0.005082352346476526
# Information Gain for attribute W: 0.08583638607684724
# Information Gain for attribute FINAL_MARGIN: 0.01784420817875626
# Information Gain for attribute SHOT_NUMBER: 0.017170255360849707
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.08028448947844069
# Information Gain for attribute DRIBBLES: 0.008140423008947018
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0
# Information Gain for attribute FINAL_MARGIN: 0.04678484847737541
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.09130503043715804
# Information Gain for attribute DRIBBLES: 0.01437846047807867
#
# Working . . .
# Information Gain for attribute LOCATION: 0.07290559532005603
# Information Gain for attribute FINAL_MARGIN: 0.07290559532005603
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.7219280948873623
#
# Working . . .
# Information Gain for attribute LOCATION: 0.008986624929939513
# Information Gain for attribute FINAL_MARGIN: 0.052654760400179024
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.19919117293110944
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0019055645046179293
# Information Gain for attribute FINAL_MARGIN: 0.12324791321663808
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute LOCATION: 0.2516291673878229
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0011236680040460079
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.017036219310794798
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute SHOT_CLOCK: 0.26661264341447544
# Information Gain for attribute DRIBBLES: 0.017036219310794798
#
# Working . . .
# Information Gain for attribute LOCATION: 0.005977711423774124
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute DRIBBLES: 0.0
#
# Working . . .
# Information Gain for attribute LOCATION: 1.7434258480109044e-05
# Information Gain for attribute W: 0.0031936957586965464
# Information Gain for attribute FINAL_MARGIN: 0.002195017721993653
# Information Gain for attribute SHOT_NUMBER: 0.0002816704616028648
# Information Gain for attribute GAME_CLOCK: 1.3299087299412093e-05
# Information Gain for attribute SHOT_CLOCK: 1.1000038370234666e-05
# Information Gain for attribute DRIBBLES: 0.000505912479330628
#
# Working . . .
# Information Gain for attribute LOCATION: 0.00017700465486725214
# Information Gain for attribute FINAL_MARGIN: 0.00028748787759103056
# Information Gain for attribute SHOT_NUMBER: 0.0005345091645685349
# Information Gain for attribute GAME_CLOCK: 0.00045919700262231355
# Information Gain for attribute SHOT_CLOCK: 0.00031943553195457053
# Information Gain for attribute DRIBBLES: 0.002657772941713765
# Working . . .
# Information Gain for attribute LOCATION: 2.9772828728624745e-05
# Information Gain for attribute FINAL_MARGIN: 0.00010672850460369254
# Information Gain for attribute SHOT_NUMBER: 0.0009094337813642522
# Information Gain for attribute GAME_CLOCK: 8.919137221541362e-05
# Information Gain for attribute SHOT_CLOCK: 0.0033348028881578506
#
# Working . . .
# Information Gain for attribute LOCATION: 0.00028394986708302206
# Information Gain for attribute FINAL_MARGIN: 0.001705140648852077
# Information Gain for attribute SHOT_NUMBER: 0.00021893688837509168
# Information Gain for attribute GAME_CLOCK: 7.680821133448923e-05
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0004058600981231564
# Information Gain for attribute SHOT_NUMBER: -4.163336342344337e-17
# Information Gain for attribute GAME_CLOCK: 0.00023123903879684882
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.00023277986497310943
# Information Gain for attribute GAME_CLOCK: 9.146839828444442e-06
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 3.7496450555618566e-06
#
# Working . . .
# Information Gain for attribute SHOT_NUMBER: 0.0054008083881982305
# Information Gain for attribute GAME_CLOCK: 0.000686836309327421
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0010019555070813757
#
# Working . . .
# Information Gain for attribute LOCATION: 0.003954106302977156
# Information Gain for attribute SHOT_NUMBER: 0.04948381594846696
# Information Gain for attribute GAME_CLOCK: 0.002041201789305891
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0009857482833732778
# Information Gain for attribute GAME_CLOCK: 0.00012545895565119203
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 1.1102230246251565e-16
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0010821659130775263
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0008453619713243432
# Information Gain for attribute FINAL_MARGIN: 0.00015071886169337745
# Information Gain for attribute SHOT_NUMBER: 0.001642697650867657
# Information Gain for attribute GAME_CLOCK: 0.0004770901917033332
#
# Working . . .
# Information Gain for attribute LOCATION: 0.040655550881068314
# Information Gain for attribute FINAL_MARGIN: 0.033665528947902756
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.04306839587828004
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute LOCATION: 0.0015239371928211787
# Information Gain for attribute FINAL_MARGIN: 7.484455260342582e-05
# Information Gain for attribute GAME_CLOCK: 0.0009975031757171737
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0013739035018359713
# Information Gain for attribute GAME_CLOCK: 0.014792611343523998
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.033208366733651684
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.007296511018691332
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0025825292643255615
# Information Gain for attribute GAME_CLOCK: 0.0013758611826168998
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.00041122793603554086
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.09027634939276519
#
# Working . . .
# Information Gain for attribute LOCATION: 0.016135496534904648
# Information Gain for attribute FINAL_MARGIN: 0.000973764956520462
# Information Gain for attribute SHOT_NUMBER: 5.642018716803948e-05
# Information Gain for attribute GAME_CLOCK: 0.019080350575325977
# Information Gain for attribute SHOT_CLOCK: 0.01941150508647088
#
# Working . . .
# Information Gain for attribute LOCATION: 0.044427197765431914
# Information Gain for attribute FINAL_MARGIN: 9.221505878820313e-05
# Information Gain for attribute SHOT_NUMBER: 0.007216473100212041
# Information Gain for attribute GAME_CLOCK: 0.0030121908121470975
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.002884853587726055
# Information Gain for attribute SHOT_NUMBER: 0.008759293005954044
# Information Gain for attribute GAME_CLOCK: 0.0013653507075550575
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.0
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.007118369749138265
# Information Gain for attribute GAME_CLOCK: 1.1102230246251565e-16
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.034851554559677256
#
# Working . . .
# Information Gain for attribute GAME_CLOCK: 0.17095059445466854
#
# Working . . .
# Information Gain for attribute FINAL_MARGIN: 0.0297689664846863
# Information Gain for attribute SHOT_NUMBER: 0.03181722483764038
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-427cbadb29e1> in <module>()
#      17
#      18 if __name__ == "__main__":
# ---> 19     main()
#
# <ipython-input-31-427cbadb29e1> in main()
#       2     dt = DT()
#       3     print("Build model:")
# ----> 4     dt.build_model()
#       5     dt.print_model()
#       6
#
# <ipython-input-30-412259a31dab> in build_model(self)
#     234         #         (key, count) tuples; we need to take the first element of the list and the first element of the tuple
#     235         self.default_class = Counter([x[IDX_TARGET] for x in self.data]).most_common(1)[0][0]
# --> 236         self.__id3(set(range(len(ATTR) - 1)), list(range(len(self.data))))
#     237
#     238     def apply_model(self, record):
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     200                 elif (self.data[r][splitting.attr] <= splitting.cond):
#     201                     less_equal.append(r)
# --> 202             self.__id3(newattrs, greater, parent_id=node_id, value=False)
#     203             self.__id3(newattrs, less_equal, parent_id=node_id, value=True)
#     204
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     209                     if(self.data[r][splitting.attr] == sc):
#     210                         subset.append(r)
# --> 211                 self.__id3(newattrs, subset, parent_id=node_id, value=sc)
#     212
#     213
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     200                 elif (self.data[r][splitting.attr] <= splitting.cond):
#     201                     less_equal.append(r)
# --> 202             self.__id3(newattrs, greater, parent_id=node_id, value=False)
#     203             self.__id3(newattrs, less_equal, parent_id=node_id, value=True)
#     204
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     200                 elif (self.data[r][splitting.attr] <= splitting.cond):
#     201                     less_equal.append(r)
# --> 202             self.__id3(newattrs, greater, parent_id=node_id, value=False)
#     203             self.__id3(newattrs, less_equal, parent_id=node_id, value=True)
#     204
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     209                     if(self.data[r][splitting.attr] == sc):
#     210                         subset.append(r)
# --> 211                 self.__id3(newattrs, subset, parent_id=node_id, value=sc)
#     212
#     213
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     209                     if(self.data[r][splitting.attr] == sc):
#     210                         subset.append(r)
# --> 211                 self.__id3(newattrs, subset, parent_id=node_id, value=sc)
#     212
#     213
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     201                     less_equal.append(r)
#     202             self.__id3(newattrs, greater, parent_id=node_id, value=False)
# --> 203             self.__id3(newattrs, less_equal, parent_id=node_id, value=True)
#     204
#     205         if(splitting.split_type == SplitType.multi):
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     200                 elif (self.data[r][splitting.attr] <= splitting.cond):
#     201                     less_equal.append(r)
# --> 202             self.__id3(newattrs, greater, parent_id=node_id, value=False)
#     203             self.__id3(newattrs, less_equal, parent_id=node_id, value=True)
#     204
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     209                     if(self.data[r][splitting.attr] == sc):
#     210                         subset.append(r)
# --> 211                 self.__id3(newattrs, subset, parent_id=node_id, value=sc)
#     212
#     213
#
# <ipython-input-30-412259a31dab> in __id3(self, attrs, records, parent_id, value)
#     182
#     183         # find the attribute with the largest gain
# --> 184         splitting = self.__find_best_attr(attrs, records)
#     185         # add node
#     186         node_id = self.__add_node(parent_id, edge_value=value, val=splitting.attr,
#
# <ipython-input-30-412259a31dab> in __find_best_attr(self, attrs, records)
#      85             elif ATTR[a].type == AttrType.num:  # numerical attribute => binary split on median value
#      86                 split_mode = SplitType.bin
# ---> 87                 split_cond = self.__median(a)  # (i.e., if less or equal than this value)
#      88
#      89                 greater = []
#
# <ipython-input-30-412259a31dab> in __median(self, attrNum)
#      26         for i in range(len(self.data)):
#      27             attrList.append(self.data[i][attrNum])
# ---> 28         return median(attrList)
#      29
#      30
#
# C:\Users\EJS\Anaconda3\lib\statistics.py in median(data)
#     376     """
#     377     data = sorted(data)
# --> 378     n = len(data)
#     379     if n == 0:
#     380         raise StatisticsError("no median for empty data")
#
# KeyboardInterrupt:
